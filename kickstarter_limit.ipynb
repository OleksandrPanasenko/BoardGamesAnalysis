# %% [markdown]
# Tasks:
# 1. Upload dataset
# 2. See through columns
# 3. Separate board games into dataframe
# 4. Choose columns
# 5. Save into csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_full=pd.read_csv('Kickstarter_scrapped.csv')

# %%
df_full.head()
# Out:
#    backers_count                                              blurb  \
# 0             17  STL FILES FOR 3D PRINTING - 75 mm & 32 mm - Pr...
# 1             21  3D Printable (STL Files) - 32 mm & 75 mm - Min...
# 2              1  Modern Compact Design | Built-in Player Desks ...
# 3             28  STL FILES FOR 3D PRINTING - 75 mm & 32 mm - MI...
# 4             16  Anime STL File 3d Print Fanart Collectable Bow...
#
#    categoryId    categoryName          categorySlug  converted_pledged_amount  \
# 0          34  Tabletop Games  games/tabletop games                       175
# 1          34  Tabletop Games  games/tabletop games                       228
# 2          34  Tabletop Games  games/tabletop games                        19
# 3          34  Tabletop Games  games/tabletop games                       504
# 4          34  Tabletop Games  games/tabletop games                       260
#
#   country country_displayable_name  created_at  \
# ...

# %%
df_full['category'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df_full.columns
# Out:
# Index(['Unnamed: 0', 'id', 'photo', 'name', 'blurb', 'goal', 'pledged',
#        'state', 'slug', 'disable_communication', 'country', 'currency',
#        'currency_symbol', 'currency_trailing_code', 'deadline',
#        'state_changed_at', 'created_at', 'launched_at', 'staff_pick',
#        'backers_count', 'static_usd_rate', 'usd_pledged', 'creator',
#        'location', 'category', 'profile', 'spotlight', 'urls', 'source_url',
#        'friends', 'is_starred', 'is_backing', 'permissions', 'name_len',
#        'name_len_clean', 'blurb_len', 'blurb_len_clean', 'deadline_weekday',
#        'state_changed_at_weekday', 'created_at_weekday', 'launched_at_weekday',
#        'deadline_month', 'deadline_day', 'deadline_yr', 'deadline_hr',
#        'state_changed_at_month', 'state_changed_at_day', 'state_changed_at_yr',
#        'state_changed_at_hr', 'created_at_month', 'created_at_day',
#        'created_at_yr', 'created_at_hr', 'launched_at_month',
# ...

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20632 entries, 0 to 20631
# Data columns (total 68 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   20632 non-null  int64
#  1   id                           20632 non-null  int64
#  2   photo                        20632 non-null  object
#  3   name                         20632 non-null  object
#  4   blurb                        20626 non-null  object
#  5   goal                         20632 non-null  float64
#  6   pledged                      20632 non-null  float64
#  7   state                        20632 non-null  object
#  8   slug                         20632 non-null  object
#  9   disable_communication        20632 non-null  bool
#  10  country                      20632 non-null  object
#  11  currency                     20632 non-null  object
#  12  currency_symbol              20632 non-null  object
# ...

# %%
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20632 entries, 0 to 20631
# Data columns (total 60 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                20632 non-null  int64
#  1   id                        20632 non-null  int64
#  2   photo                     20632 non-null  object
#  3   name                      20632 non-null  object
#  4   blurb                     20626 non-null  object
#  5   goal                      20632 non-null  float64
#  6   pledged                   20632 non-null  float64
#  7   state                     20632 non-null  object
#  8   slug                      20632 non-null  object
#  9   disable_communication     20632 non-null  bool
#  10  country                   20632 non-null  object
#  11  currency                  20632 non-null  object
#  12  currency_symbol           20632 non-null  object
# ...

# %%
df_features.columns
# Out:
# Index(['Unnamed: 0', 'id', 'photo', 'name', 'blurb', 'goal', 'pledged',
#        'state', 'slug', 'disable_communication', 'country', 'currency',
#        'currency_symbol', 'currency_trailing_code', 'deadline',
#        'state_changed_at', 'created_at', 'launched_at', 'staff_pick',
#        'backers_count', 'static_usd_rate', 'usd_pledged', 'creator',
#        'location', 'category', 'profile', 'spotlight', 'urls', 'source_url',
#        'friends', 'is_starred', 'is_backing', 'permissions', 'name_len',
#        'name_len_clean', 'blurb_len', 'blurb_len_clean', 'deadline_weekday',
#        'state_changed_at_weekday', 'created_at_weekday', 'launched_at_weekday',
#        'deadline_month', 'deadline_day', 'deadline_yr', 'deadline_hr',
#        'state_changed_at_month', 'state_changed_at_day', 'state_changed_at_yr',
#        'state_changed_at_hr', 'created_at_month', 'created_at_day',
#        'created_at_yr', 'created_at_hr', 'launched_at_month',
# ...

# %%
difference_categories=[item for item in df_full.columns if item not in df_features.columns]
difference_categories
# Out:
# ['create_to_launch_days',
#  'launch_to_deadline_days',
#  'launch_to_state_change_days',
#  'SuccessfulBool',
#  'USorGB',
#  'TOPCOUNTRY',
#  'LaunchedTuesday',
#  'DeadlineWeekend']

# %%
df=df_full

# %%
df.shape
# Out:
# (20632, 68)

# %%
df['category'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 20632 entries, 0 to 20631
# Series name: category
# Non-Null Count  Dtype
# --------------  -----
# 18743 non-null  object
# dtypes: object(1)
# memory usage: 161.3+ KB

# %%
df[df['category']=='Plays']
# Out:
#       Unnamed: 0          id  \
# 1040        1040  1283642423
# 1041        1041  1364292288
# 1042        1042  2113800995
# 1043        1043   191825716
# 1044        1044  1505170596
# ...          ...         ...
# 2496        2496    50031388
# 2497        2497  1628743025
# 2498        2498  1978116151
# 2499        2499   205873840
# 2500        2500   596306139
#
#                                                   photo  \
# 1040  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 1041  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 1042  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 1043  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 1044  {"small":"https://ksr-ugc.imgix.net/assets/011...
# ...                                                 ...
# 2496  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 2497  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 2498  {"small":"https://ksr-ugc.imgix.net/assets/014...
# ...

# %%
df[df['blurb'].astype(str).str.lower().str.contains('board game')]
# Out:
#        Unnamed: 0        id  \
# 12580       12580  95274372
#
#                                                    photo       name  \
# 12580  {"small":"https://ksr-ugc.imgix.net/assets/012...  LUMA DICE
#
#                                                    blurb     goal    pledged  \
# 12580  LUMA DICE, Metal LED Powered Light Dice. The c...  15000.0  257872.42
#
#             state       slug  disable_communication  ...  \
# 12580  successful  luma-dice                  False  ...
#
#                launch_to_deadline      launch_to_state_change  \
# 12580  55 days 00:00:00.000000000  55 days 00:00:00.000000000
#
#       create_to_launch_days  launch_to_deadline_days  \
# 12580                    38                       55
#
#       launch_to_state_change_days SuccessfulBool USorGB TOPCOUNTRY  \
# 12580                          55              1      0          0
#
#        LaunchedTuesday  DeadlineWeekend
# 12580                0                0
#
# [1 rows x 68 columns]

# %%
df[df['name'].astype(str).str.lower().str.contains('gloomhaven')]
# Out:
# Empty DataFrame
# ...

# %%
df.columns[df.columns.astype(str).str.contains('usd')]
# Out:
# Index(['static_usd_rate', 'usd_pledged'], dtype='object')

# %%
df.columns[df.columns.astype(str).str.contains('status')]
# Out:
# Index([], dtype='object')

# %%
df[df['pledged']>=df['goal']]
# Out:
#        Unnamed: 0          id  \
# 180           180   106949155
# 181           181   981191593
# 182           182   287075459
# 183           183   452553374
# 184           184  2089019908
# ...           ...         ...
# 19993       19993  1555773146
# 19994       19994  1694862779
# 19995       19995  1703378682
# 19996       19996  1295738295
# 19997       19997    55009436
#
#                                                    photo  \
# 180    {"small":"https://ksr-ugc.imgix.net/assets/012...
# 181    {"small":"https://ksr-ugc.imgix.net/assets/011...
# 182    {"small":"https://ksr-ugc.imgix.net/assets/011...
# 183    {"small":"https://ksr-ugc.imgix.net/assets/011...
# 184    {"small":"https://ksr-ugc.imgix.net/assets/012...
# ...                                                  ...
# 19993  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 19994  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 19995  {"small":"https://ksr-ugc.imgix.net/assets/011...
# ...

# %%
label='How many kickstarter projects reach their goals?'
plt.bar(height=(df['pledged']>=df['goal']).value_counts(),x=(df['pledged']>=df['goal']).value_counts().index.astype(str))
plt.title(label)
# Out:
# Text(0.5, 1.0, 'How many kickstarter projects reach their goals?')
